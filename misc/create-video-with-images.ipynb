# %% [markdown]
# # Video creation from images

# %%
import os
from google.auth import default
from googleapiclient.discovery import build

os.environ.get('GOOGLE_APPLICATION_CREDENTIALS')
driveService = build("drive", "v3")

# %% [markdown]
# ## What is the plan ?
#
# * List all files and sort by creation date
# * Download one at a time to create the video
#
# ## List all files and sort by creation date

# %%
results = driveService.files().list(pageSize=10).execute()
results
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 results = driveService.files().list(pageSize=10).execute()
#       2 results
#
# File ~/Workspace/personal/Notebooks/.venv/lib/python3.12/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/Workspace/personal/Notebooks/.venv/lib/python3.12/site-packages/googleapiclient/http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
# ...
